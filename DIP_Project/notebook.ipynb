# %%
from google.colab import drive
import os

drive.mount('/content/drive')


project_path = "/content/drive/MyDrive/DIP_Project/"
degraded_dir = os.path.join(project_path, "degraded/")
preprocessed_dir = os.path.join(project_path, "preprocessed/")
robin_input_dir = os.path.join(project_path, "robin_input/")
robin_output_dir = os.path.join(project_path, "robin_output/")

for folder in [degraded_dir, preprocessed_dir, robin_input_dir, robin_output_dir]:
    os.makedirs(folder, exist_ok=True)

print("Google Drive mounted and folders ready.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Google Drive mounted and folders ready.

# %%
# !pip install opencv-python-headless scikit-image matplotlib
# Out:
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (0.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python-headless) (2.0.2)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (1.16.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (3.5)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (2025.9.9)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import cv2
import numpy as np

def preprocess_image(path, save_path):
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)

    # Gaussian Blur
    blur = cv2.GaussianBlur(img, (5,5), 0)

    # Otsu Thresholding
    _, otsu = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    # Morphological Closing
    kernel = np.ones((3,3), np.uint8)
    morph = cv2.morphologyEx(otsu, cv2.MORPH_CLOSE, kernel)

    cv2.imwrite(save_path, morph)


for fname in os.listdir(degraded_dir):
    if fname.endswith(".png"):
        in_path = os.path.join(degraded_dir, fname)
        out_path = os.path.join(preprocessed_dir, fname)
        preprocess_image(in_path, out_path)

print("DIP preprocessing completed. Files saved in:", preprocessed_dir)
# Out:
# DIP preprocessing completed. Files saved in: /content/drive/MyDrive/DIP_Project/preprocessed/

# %%
# %cd /content
# !git clone https://github.com/masyagin1998/robin.git
# %cd robin
# !pip install -r requirements.txt

# Download pretrained weights
# !wget -O model_weights.zip https://www.dropbox.com/s/vrlcbdhfbvn82pi/model_weights.zip?dl=1
# !unzip model_weights.zip -d model_weights
# Out:
# /content
# fatal: destination path 'robin' already exists and is not an empty directory.
# /content/robin
# Collecting numpy==1.22.0 (from -r requirements.txt (line 1))
#   Using cached numpy-1.22.0.zip (11.3 MB)
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# --2025-10-03 17:09:26--  https://www.dropbox.com/s/vrlcbdhfbvn82pi/model_weights.zip?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/lyrlt7wh82slnz9eyg5ms/model_weights.zip?rlkey=tkp9ofozkktfmdxj4xhon4bz0&dl=1 [following]
# --2025-10-03 17:09:26--  https://www.dropbox.com/scl/fi/lyrlt7wh82slnz9eyg5ms/model_weights.zip?rlkey=tkp9ofozkktfmdxj4xhon4bz0&dl=1
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc8c3c16369675402c30e02a42b.dl.dropboxusercontent.com/cd/0/inline/Cyhrn7AMP0uB8h61jP_wB-oPeEVKJ32n3ciEK5yLWg5mmjNVdl8OHH0XDOC-QJEg-iyEoYSQiZDTxs1D1ZUgdgeVRcz5hleWf8tAXig0yNvfTAOz6JN8JuehRMGKQp1d-JGMnK6NKhTcrqkS3Qk9Kc6V/file?dl=1# [following]
# --2025-10-03 17:09:27--  https://ucc8c3c16369675402c30e02a42b.dl.dropboxusercontent.com/cd/0/inline/Cyhrn7AMP0uB8h61jP_wB-oPeEVKJ32n3ciEK5yLWg5mmjNVdl8OHH0XDOC-QJEg-iyEoYSQiZDTxs1D1ZUgdgeVRcz5hleWf8tAXig0yNvfTAOz6JN8JuehRMGKQp1d-JGMnK6NKhTcrqkS3Qk9Kc6V/file?dl=1
# Resolving ucc8c3c16369675402c30e02a42b.dl.dropboxusercontent.com (ucc8c3c16369675402c30e02a42b.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to ucc8c3c16369675402c30e02a42b.dl.dropboxusercontent.com (ucc8c3c16369675402c30e02a42b.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CyhF3GLkQmcGBD5h4mk_gIr9GWk7imovW5_VLScvJQCKOeQ3HGahij9i0Phon2uPT21n6XJpOJNLEup5JwfmFdP4K0kcZXNidvJVtodNnT5bnfinnJy7bXOXy3VAcZ13juxqRuD1eucoaTz9yxmJJoESa2pbKFobk-rZi9AeqxR0jAw7B1dKaGYGYqMaxrecdrv9GRPfqxMinm5v3rRFWOMycBkyPpjJwZbZybjOA6HTBq78sdaV9op7zlSz8xTQ00YvZUQB7T37Z8FTEqiIdy6GzRivomTofkFiEHJjTdg1FCJJJIdIove-fZ0rdDvCuK3gpHyd0I44JdFaOa0R17ceYSHvy2qffe_6UVqHyyAlkK6DeOwaAdJrjCufd7P0eO0/file?dl=1 [following]
# --2025-10-03 17:09:28--  https://ucc8c3c16369675402c30e02a42b.dl.dropboxusercontent.com/cd/0/inline2/CyhF3GLkQmcGBD5h4mk_gIr9GWk7imovW5_VLScvJQCKOeQ3HGahij9i0Phon2uPT21n6XJpOJNLEup5JwfmFdP4K0kcZXNidvJVtodNnT5bnfinnJy7bXOXy3VAcZ13juxqRuD1eucoaTz9yxmJJoESa2pbKFobk-rZi9AeqxR0jAw7B1dKaGYGYqMaxrecdrv9GRPfqxMinm5v3rRFWOMycBkyPpjJwZbZybjOA6HTBq78sdaV9op7zlSz8xTQ00YvZUQB7T37Z8FTEqiIdy6GzRivomTofkFiEHJjTdg1FCJJJIdIove-fZ0rdDvCuK3gpHyd0I44JdFaOa0R17ceYSHvy2qffe_6UVqHyyAlkK6DeOwaAdJrjCufd7P0eO0/file?dl=1
# Reusing existing connection to ucc8c3c16369675402c30e02a42b.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 701936562 (669M) [application/binary]
# Saving to: ‘model_weights.zip’
#
# model_weights.zip   100%[===================>] 669.42M  58.4MB/s    in 11s
#
# 2025-10-03 17:09:39 (59.4 MB/s) - ‘model_weights.zip’ saved [701936562/701936562]
#
# Archive:  model_weights.zip
# replace model_weights/model_weights/2Stage_GAN/dis_2_93.2836.pth? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: model_weights/model_weights/2Stage_GAN/dis_2_93.2836.pth
#   inflating: model_weights/model_weights/2Stage_GAN/unet_0_2_93.2836.pth
#   inflating: model_weights/model_weights/2Stage_GAN/unet_1_2_93.2836.pth
#   inflating: model_weights/model_weights/2Stage_GAN/unet_2_2_93.2836.pth
#   inflating: model_weights/model_weights/2Stage_GAN/unet_3_2_93.2836.pth
#   inflating: model_weights/model_weights/DeepOtsu/train_model_fusion_11k-log/checkpoint
#   inflating: model_weights/model_weights/DeepOtsu/train_model_fusion_11k-log/model.ckpt.data-00000-of-00001
#   inflating: model_weights/model_weights/DeepOtsu/train_model_fusion_11k-log/model.ckpt.index
#   inflating: model_weights/model_weights/DeepOtsu/train_model_fusion_11k-log/model.ckpt.meta
#   inflating: model_weights/model_weights/DPLink/dibco_dplinknet34.th
#   inflating: model_weights/model_weights/Robin/bin_weights.hdf5
#   inflating: model_weights/model_weights/SAE/model_weights_dibco_4_256x256_s128_f64_k3_s2_se1_e200_b10_esp.h5
#   inflating: model_weights/model_weights/Sauvola-Net/Sauvalo_Finetune_E48-Acc0.9919-Tacc0.9280-F0.9297-PSNRinf.h5

# %%
import shutil
for fname in os.listdir(preprocessed_dir):
    if fname.endswith(".png"):
        shutil.copy(os.path.join(preprocessed_dir, fname), robin_input_dir)

# %%
# !python /content/robin/src/unet/binarize.py \
  --input "{robin_input_dir}" \
  --output "{robin_output_dir}" \
  --weights "/content/robin/model_weights/model_weights/Robin/bin_weights.hdf5"
# Out:
# 2025-10-03 17:28:04.125337: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759512484.159686   24885 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759512484.170058   24885 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1759512484.198292   24885 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759512484.198339   24885 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759512484.198348   24885 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759512484.198354   24885 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-03 17:28:04.203980: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-03 17:28:08.854385: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1759512488.854535   24885 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Model weights loaded from: /content/robin/model_weights/model_weights/Robin/bin_weights.hdf5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759512491.500547   24924 service.cc:152] XLA service 0x7f901c021350 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759512491.500582   24924 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2025-10-03 17:28:11.559159: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1759512491.841446   24924 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2025-10-03 17:28:12.152679: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.69 = (f32[20,32,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,1,128,128]{3,2,1,0} %bitcast.1944, f32[32,1,3,3]{3,2,1,0} %bitcast.1951, f32[32]{0} %bitcast.1953), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:12.246416: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.70 = (f32[20,32,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,32,128,128]{3,2,1,0} %bitcast.1982, f32[32,32,3,3]{3,2,1,0} %bitcast.1989, f32[32]{0} %bitcast.1991), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1_2/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:12.525269: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.71 = (f32[20,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,32,64,64]{3,2,1,0} %bitcast.2024, f32[64,32,3,3]{3,2,1,0} %bitcast.2031, f32[64]{0} %bitcast.2033), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_2_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:12.624057: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.72 = (f32[20,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,64,64,64]{3,2,1,0} %bitcast.2064, f32[64,64,3,3]{3,2,1,0} %bitcast.2071, f32[64]{0} %bitcast.2073), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_3_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:12.767677: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.73 = (f32[20,128,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,64,32,32]{3,2,1,0} %bitcast.2105, f32[128,64,3,3]{3,2,1,0} %bitcast.2112, f32[128]{0} %bitcast.2114), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_4_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:12.842682: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.74 = (f32[20,128,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,128,32,32]{3,2,1,0} %bitcast.2145, f32[128,128,3,3]{3,2,1,0} %bitcast.2152, f32[128]{0} %bitcast.2154), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_5_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:12.961072: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.75 = (f32[20,256,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,128,16,16]{3,2,1,0} %bitcast.2186, f32[256,128,3,3]{3,2,1,0} %bitcast.2193, f32[256]{0} %bitcast.2195), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_6_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:13.032643: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.76 = (f32[20,256,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,256,16,16]{3,2,1,0} %bitcast.2226, f32[256,256,3,3]{3,2,1,0} %bitcast.2233, f32[256]{0} %bitcast.2235), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_7_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:13.138716: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.77 = (f32[20,512,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,256,8,8]{3,2,1,0} %bitcast.2267, f32[512,256,3,3]{3,2,1,0} %bitcast.2274, f32[512]{0} %bitcast.2276), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_8_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:13.225500: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.78 = (f32[20,512,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,512,8,8]{3,2,1,0} %bitcast.2307, f32[512,512,3,3]{3,2,1,0} %bitcast.2314, f32[512]{0} %bitcast.2316), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_9_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:13.396888: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.79 = (f32[20,1024,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,512,4,4]{3,2,1,0} %bitcast.2348, f32[1024,512,3,3]{3,2,1,0} %bitcast.2355, f32[1024]{0} %bitcast.2357), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_10_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:13.902890: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.80 = (f32[20,1024,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,1024,4,4]{3,2,1,0} %bitcast.2388, f32[1024,1024,3,3]{3,2,1,0} %bitcast.2395, f32[1024]{0} %bitcast.2397), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_11_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:14.351923: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.81 = (f32[20,512,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,1536,8,8]{3,2,1,0} %bitcast.2435, f32[512,1536,3,3]{3,2,1,0} %bitcast.2442, f32[512]{0} %bitcast.2444), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_12_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:14.729054: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.83 = (f32[20,256,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,768,16,16]{3,2,1,0} %bitcast.2522, f32[256,768,3,3]{3,2,1,0} %bitcast.2529, f32[256]{0} %bitcast.2531), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_14_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:15.009912: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.85 = (f32[20,128,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,384,32,32]{3,2,1,0} %bitcast.2609, f32[128,384,3,3]{3,2,1,0} %bitcast.2616, f32[128]{0} %bitcast.2618), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_16_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:15.404928: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.87 = (f32[20,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,192,64,64]{3,2,1,0} %bitcast.2696, f32[64,192,3,3]{3,2,1,0} %bitcast.2703, f32[64]{0} %bitcast.2705), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_18_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:15.946693: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.89 = (f32[20,32,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,96,128,128]{3,2,1,0} %bitcast.2783, f32[32,96,3,3]{3,2,1,0} %bitcast.2790, f32[32]{0} %bitcast.2792), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_20_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# I0000 00:00:1759512497.518211   24924 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step2025-10-03 17:28:20.004221: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.69 = (f32[18,32,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[18,1,128,128]{3,2,1,0} %bitcast.1944, f32[32,1,3,3]{3,2,1,0} %bitcast.1951, f32[32]{0} %bitcast.1953), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:20.126838: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.70 = (f32[18,32,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[18,32,128,128]{3,2,1,0} %bitcast.1982, f32[32,32,3,3]{3,2,1,0} %bitcast.1989, f32[32]{0} %bitcast.1991), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1_2/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:20.280950: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.71 = (f32[18,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[18,32,64,64]{3,2,1,0} %bitcast.2024, f32[64,32,3,3]{3,2,1,0} %bitcast.2031, f32[64]{0} %bitcast.2033), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_2_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:20.378851: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.72 = (f32[18,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[18,64,64,64]{3,2,1,0} %bitcast.2064, f32[64,64,3,3]{3,2,1,0} %bitcast.2071, f32[64]{0} %bitcast.2073), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_3_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:20.517747: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.73 = (f32[18,128,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[18,64,32,32]{3,2,1,0} %bitcast.2105, f32[128,64,3,3]{3,2,1,0} %bitcast.2112, f32[128]{0} %bitcast.2114), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_4_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:20.588782: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.74 = (f32[18,128,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[18,128,32,32]{3,2,1,0} %bitcast.2145, f32[128,128,3,3]{3,2,1,0} %bitcast.2152, f32[128]{0} %bitcast.2154), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_5_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:20.703842: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.75 = (f32[18,256,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[18,128,16,16]{3,2,1,0} %bitcast.2186, f32[256,128,3,3]{3,2,1,0} %bitcast.2193, f32[256]{0} %bitcast.2195), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_6_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:20.771900: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.76 = (f32[18,256,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[18,256,16,16]{3,2,1,0} %bitcast.2226, f32[256,256,3,3]{3,2,1,0} %bitcast.2233, f32[256]{0} %bitcast.2235), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_7_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:20.874495: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.77 = (f32[18,512,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[18,256,8,8]{3,2,1,0} %bitcast.2267, f32[512,256,3,3]{3,2,1,0} %bitcast.2274, f32[512]{0} %bitcast.2276), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_8_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:20.963438: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.78 = (f32[18,512,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[18,512,8,8]{3,2,1,0} %bitcast.2307, f32[512,512,3,3]{3,2,1,0} %bitcast.2314, f32[512]{0} %bitcast.2316), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_9_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:21.108771: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.79 = (f32[18,1024,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[18,512,4,4]{3,2,1,0} %bitcast.2348, f32[1024,512,3,3]{3,2,1,0} %bitcast.2355, f32[1024]{0} %bitcast.2357), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_10_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:21.528115: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.80 = (f32[18,1024,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[18,1024,4,4]{3,2,1,0} %bitcast.2388, f32[1024,1024,3,3]{3,2,1,0} %bitcast.2395, f32[1024]{0} %bitcast.2397), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_11_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:21.887228: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.81 = (f32[18,512,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[18,1536,8,8]{3,2,1,0} %bitcast.2435, f32[512,1536,3,3]{3,2,1,0} %bitcast.2442, f32[512]{0} %bitcast.2444), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_12_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:22.260792: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.83 = (f32[18,256,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[18,768,16,16]{3,2,1,0} %bitcast.2522, f32[256,768,3,3]{3,2,1,0} %bitcast.2529, f32[256]{0} %bitcast.2531), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_14_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:22.616490: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.85 = (f32[18,128,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[18,384,32,32]{3,2,1,0} %bitcast.2609, f32[128,384,3,3]{3,2,1,0} %bitcast.2616, f32[128]{0} %bitcast.2618), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_16_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:22.931199: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.87 = (f32[18,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[18,192,64,64]{3,2,1,0} %bitcast.2696, f32[64,192,3,3]{3,2,1,0} %bitcast.2703, f32[64]{0} %bitcast.2705), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_18_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:23.399524: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.89 = (f32[18,32,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[18,96,128,128]{3,2,1,0} %bitcast.2783, f32[32,96,3,3]{3,2,1,0} %bitcast.2790, f32[32]{0} %bitcast.2792), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_20_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 774ms/step
# Saved: /content/drive/MyDrive/DIP_Project/robin_output/H01_out.png
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step2025-10-03 17:28:25.187549: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.69 = (f32[17,32,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,1,128,128]{3,2,1,0} %bitcast.1944, f32[32,1,3,3]{3,2,1,0} %bitcast.1951, f32[32]{0} %bitcast.1953), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:25.262381: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.70 = (f32[17,32,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,32,128,128]{3,2,1,0} %bitcast.1982, f32[32,32,3,3]{3,2,1,0} %bitcast.1989, f32[32]{0} %bitcast.1991), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1_2/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:25.397064: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.71 = (f32[17,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,32,64,64]{3,2,1,0} %bitcast.2024, f32[64,32,3,3]{3,2,1,0} %bitcast.2031, f32[64]{0} %bitcast.2033), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_2_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:25.487702: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.72 = (f32[17,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,64,64,64]{3,2,1,0} %bitcast.2064, f32[64,64,3,3]{3,2,1,0} %bitcast.2071, f32[64]{0} %bitcast.2073), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_3_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:25.616727: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.73 = (f32[17,128,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,64,32,32]{3,2,1,0} %bitcast.2105, f32[128,64,3,3]{3,2,1,0} %bitcast.2112, f32[128]{0} %bitcast.2114), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_4_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:25.686369: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.74 = (f32[17,128,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,128,32,32]{3,2,1,0} %bitcast.2145, f32[128,128,3,3]{3,2,1,0} %bitcast.2152, f32[128]{0} %bitcast.2154), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_5_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:25.812647: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.75 = (f32[17,256,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,128,16,16]{3,2,1,0} %bitcast.2186, f32[256,128,3,3]{3,2,1,0} %bitcast.2193, f32[256]{0} %bitcast.2195), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_6_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:25.881184: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.76 = (f32[17,256,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,256,16,16]{3,2,1,0} %bitcast.2226, f32[256,256,3,3]{3,2,1,0} %bitcast.2233, f32[256]{0} %bitcast.2235), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_7_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:25.980930: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.77 = (f32[17,512,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,256,8,8]{3,2,1,0} %bitcast.2267, f32[512,256,3,3]{3,2,1,0} %bitcast.2274, f32[512]{0} %bitcast.2276), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_8_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:26.073233: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.78 = (f32[17,512,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,512,8,8]{3,2,1,0} %bitcast.2307, f32[512,512,3,3]{3,2,1,0} %bitcast.2314, f32[512]{0} %bitcast.2316), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_9_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:26.332752: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.79 = (f32[17,1024,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,512,4,4]{3,2,1,0} %bitcast.2348, f32[1024,512,3,3]{3,2,1,0} %bitcast.2355, f32[1024]{0} %bitcast.2357), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_10_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:26.610131: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.80 = (f32[17,1024,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,1024,4,4]{3,2,1,0} %bitcast.2388, f32[1024,1024,3,3]{3,2,1,0} %bitcast.2395, f32[1024]{0} %bitcast.2397), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_11_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:26.977511: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.81 = (f32[17,512,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,1536,8,8]{3,2,1,0} %bitcast.2435, f32[512,1536,3,3]{3,2,1,0} %bitcast.2442, f32[512]{0} %bitcast.2444), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_12_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:27.378762: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.83 = (f32[17,256,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,768,16,16]{3,2,1,0} %bitcast.2522, f32[256,768,3,3]{3,2,1,0} %bitcast.2529, f32[256]{0} %bitcast.2531), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_14_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:27.637087: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.85 = (f32[17,128,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,384,32,32]{3,2,1,0} %bitcast.2609, f32[128,384,3,3]{3,2,1,0} %bitcast.2616, f32[128]{0} %bitcast.2618), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_16_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:27.942526: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.87 = (f32[17,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,192,64,64]{3,2,1,0} %bitcast.2696, f32[64,192,3,3]{3,2,1,0} %bitcast.2703, f32[64]{0} %bitcast.2705), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_18_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:28.445750: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.89 = (f32[17,32,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[17,96,128,128]{3,2,1,0} %bitcast.2783, f32[32,96,3,3]{3,2,1,0} %bitcast.2790, f32[32]{0} %bitcast.2792), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_20_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step
# Saved: /content/drive/MyDrive/DIP_Project/robin_output/H02_out.png
# ...
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 3s/step
# Saved: /content/drive/MyDrive/DIP_Project/robin_output/H09_out.png
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Saved: /content/drive/MyDrive/DIP_Project/robin_output/H10_out.png
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step2025-10-03 17:28:59.448710: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.69 = (f32[4,32,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,1,128,128]{3,2,1,0} %bitcast.1944, f32[32,1,3,3]{3,2,1,0} %bitcast.1951, f32[32]{0} %bitcast.1953), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:59.491486: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.70 = (f32[4,32,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,32,128,128]{3,2,1,0} %bitcast.1982, f32[32,32,3,3]{3,2,1,0} %bitcast.1989, f32[32]{0} %bitcast.1991), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1_2/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:59.580136: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.71 = (f32[4,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,32,64,64]{3,2,1,0} %bitcast.2024, f32[64,32,3,3]{3,2,1,0} %bitcast.2031, f32[64]{0} %bitcast.2033), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_2_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:59.634749: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.72 = (f32[4,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,64,64,64]{3,2,1,0} %bitcast.2064, f32[64,64,3,3]{3,2,1,0} %bitcast.2071, f32[64]{0} %bitcast.2073), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_3_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:59.705426: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.73 = (f32[4,128,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,64,32,32]{3,2,1,0} %bitcast.2105, f32[128,64,3,3]{3,2,1,0} %bitcast.2112, f32[128]{0} %bitcast.2114), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_4_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:59.759373: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.74 = (f32[4,128,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,128,32,32]{3,2,1,0} %bitcast.2145, f32[128,128,3,3]{3,2,1,0} %bitcast.2152, f32[128]{0} %bitcast.2154), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_5_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:59.821757: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.75 = (f32[4,256,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,128,16,16]{3,2,1,0} %bitcast.2186, f32[256,128,3,3]{3,2,1,0} %bitcast.2193, f32[256]{0} %bitcast.2195), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_6_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:59.874358: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.76 = (f32[4,256,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,256,16,16]{3,2,1,0} %bitcast.2226, f32[256,256,3,3]{3,2,1,0} %bitcast.2233, f32[256]{0} %bitcast.2235), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_7_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:28:59.935736: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.77 = (f32[4,512,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,256,8,8]{3,2,1,0} %bitcast.2267, f32[512,256,3,3]{3,2,1,0} %bitcast.2274, f32[512]{0} %bitcast.2276), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_8_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:29:00.018990: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.78 = (f32[4,512,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,512,8,8]{3,2,1,0} %bitcast.2307, f32[512,512,3,3]{3,2,1,0} %bitcast.2314, f32[512]{0} %bitcast.2316), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_9_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:29:00.230514: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.79 = (f32[4,1024,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,512,4,4]{3,2,1,0} %bitcast.2348, f32[1024,512,3,3]{3,2,1,0} %bitcast.2355, f32[1024]{0} %bitcast.2357), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_10_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:29:00.423380: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.80 = (f32[4,1024,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,1024,4,4]{3,2,1,0} %bitcast.2388, f32[1024,1024,3,3]{3,2,1,0} %bitcast.2395, f32[1024]{0} %bitcast.2397), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_11_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:29:00.746278: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.81 = (f32[4,512,8,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,1536,8,8]{3,2,1,0} %bitcast.2435, f32[512,1536,3,3]{3,2,1,0} %bitcast.2442, f32[512]{0} %bitcast.2444), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_12_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:29:01.036146: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.83 = (f32[4,256,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,768,16,16]{3,2,1,0} %bitcast.2522, f32[256,768,3,3]{3,2,1,0} %bitcast.2529, f32[256]{0} %bitcast.2531), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_14_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:29:01.174521: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.85 = (f32[4,128,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,384,32,32]{3,2,1,0} %bitcast.2609, f32[128,384,3,3]{3,2,1,0} %bitcast.2616, f32[128]{0} %bitcast.2618), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_16_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:29:01.351487: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.87 = (f32[4,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,192,64,64]{3,2,1,0} %bitcast.2696, f32[64,192,3,3]{3,2,1,0} %bitcast.2703, f32[64]{0} %bitcast.2705), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_18_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-10-03 17:29:01.517961: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=2} for conv %cudnn-conv-bias-activation.89 = (f32[4,32,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,96,128,128]{3,2,1,0} %bitcast.2783, f32[32,96,3,3]{3,2,1,0} %bitcast.2790, f32[32]{0} %bitcast.2792), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_20_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 717ms/step
# Saved: /content/drive/MyDrive/DIP_Project/robin_output/H11_out.png
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Saved: /content/drive/MyDrive/DIP_Project/robin_output/H12_out.png
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Saved: /content/drive/MyDrive/DIP_Project/robin_output/H13_out.png
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Saved: /content/drive/MyDrive/DIP_Project/robin_output/H14_out.png
# Finished in 54.70 seconds

# %%
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Folders
orig_folder = "/content/drive/MyDrive/DIP_Project/degraded"
dip_folder = "/content/drive/MyDrive/DIP_Project/robin_input"
robin_folder = "/content/drive/MyDrive/DIP_Project/robin_output"

# Get sorted lists of image filenames
orig_files = sorted([f for f in os.listdir(orig_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))])
dip_files = sorted([f for f in os.listdir(dip_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))])
robin_files = sorted([f for f in os.listdir(robin_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))])

# Make sure all folders have the same number of images
num_images = min(len(orig_files), len(dip_files), len(robin_files))
print(f"Plotting {num_images} images...")

for i in range(num_images):
    # Read images safely
    orig_path = os.path.join(orig_folder, orig_files[i])
    dip_path = os.path.join(dip_folder, dip_files[i])
    robin_path = os.path.join(robin_folder, robin_files[i])

    orig = cv2.imread(orig_path, cv2.IMREAD_GRAYSCALE)
    dip = cv2.imread(dip_path, cv2.IMREAD_GRAYSCALE)
    robin = cv2.imread(robin_path, cv2.IMREAD_GRAYSCALE)

    if orig is None:
        print(f"Warning: Cannot read original image: {orig_files[i]}")
        continue
    if dip is None:
        print(f"Warning: Cannot read DIP image: {dip_files[i]}")
        continue
    if robin is None:
        print(f"Warning: Cannot read RoBIN image: {robin_files[i]}")
        continue

    # Plot images side by side
    plt.figure(figsize=(15,5))
    plt.subplot(1,3,1)
    plt.imshow(orig, cmap="gray")
    plt.title("Original (Degraded)")
    plt.axis('off')

    plt.subplot(1,3,2)
    plt.imshow(dip, cmap="gray")
    plt.title("DIP Preprocessing")
    plt.axis('off')

    plt.subplot(1,3,3)
    plt.imshow(robin, cmap="gray")
    plt.title("RoBIN-UNet (AI Restoration)")
    plt.axis('off')

    plt.show()
# Out:
# Plotting 14 images...

# %%
import os
import shutil
from google.colab import drive

# --- CONFIGURATION ---
# 1. Name of the folder you want to copy from the Colab runtime
FOLDER_TO_COPY = "robin"  # <-- Make sure this matches your actual output folder name

# 2. Path in your Google Drive where you want to place the folder
# Set to 'DIP_Project' to create or use a folder named 'DIP_Project' directly under My Drive.
DESTINATION_PATH_IN_DRIVE = "DIP_Project"


# --- STEP 1: Mount Google Drive ---
print("--- Step 1: Mounting Google Drive ---")
# This will prompt you to click a link, choose your account, and grant permissions.
drive.mount('/content/drive')
print("Drive mounted successfully at /content/drive/MyDrive")

# --- STEP 2: Verify Source Folder and Define Paths ---
print("\n--- Step 2: Verification and Path Setup ---")

# Define the full source path (in Colab runtime)
source_path = os.path.join("/content", FOLDER_TO_COPY)

# Define the full destination path (in Google Drive)
destination_dir = os.path.join("/content/drive/MyDrive", DESTINATION_PATH_IN_DRIVE)

# Check if the source folder exists
if not os.path.isdir(source_path):
    print(f"ERROR: Source folder not found at: {source_path}")
    print("Please check the FOLDER_TO_COPY variable.")
else:
    print(f"Source folder found: {source_path}")

    # Check if the destination directory exists, if not, create it
    if not os.path.exists(destination_dir):
        print(f"Creating destination directory: {destination_dir}")
        os.makedirs(destination_dir)

    # Define the final destination path for the copied folder
    final_destination_path = os.path.join(destination_dir, FOLDER_TO_COPY)

    # --- STEP 3: Copy the Folder using shell command ---
    print("\n--- Step 3: Copying folder to Google Drive (This may take time) ---")

    # Use the shell command 'cp -r' (copy recursively) for reliable, fast copying
    copy_command = f"cp -r '{source_path}' '{destination_dir}'"

    # Execute the shell command
    # !{copy_command}

    # --- STEP 4: Verification ---
    print("\n--- Step 4: Verification ---")
    # Check if the folder now exists in Drive
    if os.path.isdir(os.path.join(destination_dir, FOLDER_TO_COPY)):
        print(f"✅ SUCCESS: Folder '{FOLDER_TO_COPY}' successfully copied to Drive.")
        print(f"Check your Drive at: /My Drive/{DESTINATION_PATH_IN_DRIVE}/{FOLDER_TO_COPY}")
        print("Note: You may need to refresh your Google Drive window.")
    else:
        print("❌ FAILURE: Copy operation failed. Please check permissions and paths.")
# Out:
# --- Step 1: Mounting Google Drive ---
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive mounted successfully at /content/drive/MyDrive
#
# --- Step 2: Verification and Path Setup ---
# Source folder found: /content/robin
#
# --- Step 3: Copying folder to Google Drive (This may take time) ---
#
# --- Step 4: Verification ---
# ✅ SUCCESS: Folder 'robin' successfully copied to Drive.
# Check your Drive at: /My Drive/DIP_Project/robin
# Note: You may need to refresh your Google Drive window.
